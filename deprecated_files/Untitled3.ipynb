# %%
import geopandas as gpd
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (20, 10)
df_places = gpd.read_file('Benfica.geojson')

# %%
df_places.plot(color='green')
# Out:
# <AxesSubplot:>
